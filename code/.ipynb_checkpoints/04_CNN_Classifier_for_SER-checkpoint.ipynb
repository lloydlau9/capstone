# %% [markdown]
# #  CNN Classifier for  SER (Speech Emotion Recognition)

# %% [markdown]
# ## Dataset
#
# The Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS),and it is free to download. This dataset has 7356 files rated by 247 individuals 10 times on emotional validity, intensity, and genuineness. here the Speech files of all actors (01-24) will be used and the files are available under path ../datasets/RAVDESS. It contains 1440 files: 60 trials per actor x 24 actors = 1440.
# Filename identifiers:
# <ol>
# <li>Modality (01 = full-AV, 02 = video-only, 03 = audio-only).</li>
# <li>Vocal channel (01 = speech, 02 = song).</li>
# <li>Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).</li>
# <li>Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.</li>
# <li>Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").</li>
# <li>Repetition (01 = 1st repetition, 02 = 2nd repetition)..</li>
# <li>Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).</li>
# </ol>

# %% [markdown]
# ## Downloading Libraries

# %%
#!pip install librosa soundfile numpy sklearn pyaudio

# %%
#!pip install soundfile

# %%
# pip install --upgrade pip

# %%
#pip install tensorflow

# %%
#pip install keras==2.3.0

# %% [markdown]
# ## Libraries Import

# %%
import os
import os.path
import soundfile
import librosa
import time
import numpy as np
import pandas as pd
import seaborn as sn

from librosa import display
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,confusion_matrix
import joblib
import IPython.display as ipd  # To play sound in the notebook
import keras
import tensorflow as tf
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint

# %%
#import tensorflow as tf
#from tensorflow import keras
#from keras.preprocessing import sequence
#from keras.models import Sequential
#from keras.layers import Dense, Embedding
#from keras.utils import to_categorical
#from keras.layers import Input, Flatten, Dropout, Activation
#from keras.layers import Conv1D, MaxPooling1D
#from keras.models import Model
#from keras.callbacks import ModelCheckpoint

# %% [markdown]
# ### Retrieve RAVDESS dataset from File System

# %%
RAV = "../datasets/RAVDESS/"
JOBLIB = "../datasets/JOBLIB/"
dir_list = os.listdir(RAV+"Actor_01/")
dir_list[0:5]
# Out:
# ['03-01-01-01-01-01-01.wav',
#  '03-01-01-01-01-02-01.wav',
#  '03-01-01-01-02-01-01.wav',
#  '03-01-01-01-02-02-01.wav',
#  '03-01-02-01-01-01-01.wav']

# %%
#testing audio by select 1st actor(male) with sad motion
ipd.Audio(RAV + 'Actor_01/03-01-04-01-01-01-01.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data, sr = librosa.load(RAV + 'Actor_01/03-01-04-01-01-01-01.wav')
ax = {}
fig, (ax) = plt.subplots(1, 2,figsize=(15,5))
fig.suptitle('Waveform Vs Spectrogram')
ax[0].set_title("Waveform")
librosa.display.waveplot(data, sr=sr,ax=ax[0])
ax[1].set_title("Spectrogram")
Xdb = librosa.amplitude_to_db(abs(librosa.stft(data)))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz',ax=ax[1])

# %%
dir_list = os.listdir(RAV)
dir_list.sort()
lst = []
start_time = time.time()
for i in dir_list:
    try:
        fname = os.listdir(RAV + i)
        #to get all actor's relative file path
        #print(fname)
        for f in fname:
            #print(RAV + i + '/' + f)
            data, sample_rate = librosa.load(RAV + i + '/' + f, res_type='kaiser_fast')
            mfccs = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate, n_mfcc=40).T,axis=0) 
            # The instruction below converts the labels (from 1 to 8) to a series from 0 to 7
            # This is because our predictor needs to start from 0 otherwise it will try to predict also 0.
            file = int(f[7:8]) - 1 
            arr = mfccs, file
            lst.append(arr)
    except ValueError:
        continue

print("Time Taken: %s sec" % (time.time() - start_time))
# Out:
# Time Taken: 37.113667249679565 sec

# %%
# Creating X and y: zip makes a list of all the first elements, and a list of all the second elements.
X, y = zip(*lst)
X = np.asarray(X)
y = np.asarray(y)
X.shape, y.shape
# Out:
# ((1440, 40), (1440,))

# %%
# Saving joblib files to not load them again with the loop above
X_name = 'X.joblib'
y_name = 'y.joblib'
savedX = joblib.dump(X, os.path.join(JOBLIB, X_name))
savedy = joblib.dump(y, os.path.join(JOBLIB, y_name))

# %%
# Retrieve the data from the stored lib file
#X = joblib.load(JOBLIB+'X.joblib')
#y = joblib.load(JOBLIB+'y.joblib')

# %%
X.shape, y.shape
# Out:
# ((1440, 40), (1440,))

# %% [markdown]
# ## Decision Tree Classifier
# By using a decision tree to accomplish this classification model:

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.33, random_state=42)

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = dtree.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.22      0.25      0.23        28
#            1       0.40      0.35      0.37        72
#            2       0.24      0.19      0.21        58
#            3       0.23      0.33      0.27        60
#            4       0.55      0.57      0.56        60
#            5       0.29      0.44      0.35        55
#            6       0.34      0.24      0.28        74
#            7       0.44      0.33      0.38        69
#
#     accuracy                           0.34       476
#    macro avg       0.34      0.34      0.33       476
# weighted avg       0.35      0.34      0.34       476

# %% [markdown]
# ## CNN (Convolutional Neural Networks) Classifier and Fit/Train the Model

# %%
x_traincnn = np.expand_dims(X_train, axis=2)
x_testcnn = np.expand_dims(X_test, axis=2)

# %%
x_traincnn.shape, x_testcnn.shape
# Out:
# ((964, 40, 1), (476, 40, 1))

# %%
model = Sequential()

model.add(Conv1D(64, 5,padding='same',
                 input_shape=(40,1)))
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(4)))
model.add(Conv1D(128, 5,padding='same',))
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(4)))
model.add(Conv1D(256, 5,padding='same',))
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(8))
model.add(Activation('softmax'))
opt = keras.optimizers.RMSprop(lr=0.00005, rho=0.9, epsilon=1e-07, decay=0.0)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 40, 64)            384
# _________________________________________________________________
# activation (Activation)      (None, 40, 64)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 40, 64)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 10, 64)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 10, 128)           41088
# _________________________________________________________________
# activation_1 (Activation)    (None, 10, 128)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 2, 128)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 2, 256)            164096
# _________________________________________________________________
# activation_2 (Activation)    (None, 2, 256)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 256)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 4104
# _________________________________________________________________
# activation_3 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 209,672
# Trainable params: 209,672
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
cnnhistory=model.fit(x_traincnn, y_train, batch_size=16, epochs=200, validation_data=(x_testcnn, y_test))
# Out:
# Epoch 1/200
# 61/61 [==============================] - 2s 27ms/step - loss: 7.7499 - accuracy: 0.1276 - val_loss: 3.8226 - val_accuracy: 0.1450
# Epoch 2/200
# 61/61 [==============================] - 0s 4ms/step - loss: 5.3725 - accuracy: 0.1341 - val_loss: 2.3807 - val_accuracy: 0.1345
# Epoch 3/200
# 61/61 [==============================] - 0s 4ms/step - loss: 4.4424 - accuracy: 0.1400 - val_loss: 2.2387 - val_accuracy: 0.1471
# Epoch 4/200
# 61/61 [==============================] - 0s 4ms/step - loss: 4.2495 - accuracy: 0.1476 - val_loss: 2.7902 - val_accuracy: 0.1450
# Epoch 5/200
# 61/61 [==============================] - 0s 4ms/step - loss: 3.8141 - accuracy: 0.1314 - val_loss: 2.0068 - val_accuracy: 0.2269
# Epoch 6/200
# 61/61 [==============================] - 0s 4ms/step - loss: 3.5092 - accuracy: 0.1574 - val_loss: 1.9727 - val_accuracy: 0.2353
# Epoch 7/200
# 61/61 [==============================] - 0s 4ms/step - loss: 3.1743 - accuracy: 0.1473 - val_loss: 2.0242 - val_accuracy: 0.1996
# Epoch 8/200
# 61/61 [==============================] - 0s 4ms/step - loss: 3.0873 - accuracy: 0.1572 - val_loss: 2.1291 - val_accuracy: 0.2248
# Epoch 9/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.6862 - accuracy: 0.1762 - val_loss: 2.0157 - val_accuracy: 0.2164
# Epoch 10/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.5011 - accuracy: 0.1880 - val_loss: 1.9502 - val_accuracy: 0.2185
# Epoch 11/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.5245 - accuracy: 0.1413 - val_loss: 1.9390 - val_accuracy: 0.2101
# Epoch 12/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.4025 - accuracy: 0.2028 - val_loss: 1.9235 - val_accuracy: 0.2290
# Epoch 13/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.2760 - accuracy: 0.1902 - val_loss: 1.9834 - val_accuracy: 0.2227
# Epoch 14/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.3103 - accuracy: 0.1708 - val_loss: 1.9183 - val_accuracy: 0.2500
# Epoch 15/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.2242 - accuracy: 0.1914 - val_loss: 1.9446 - val_accuracy: 0.2332
# Epoch 16/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.2633 - accuracy: 0.1977 - val_loss: 1.9653 - val_accuracy: 0.2731
# Epoch 17/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.1331 - accuracy: 0.1993 - val_loss: 1.8884 - val_accuracy: 0.2920
# Epoch 18/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.0734 - accuracy: 0.2160 - val_loss: 1.8547 - val_accuracy: 0.2878
# Epoch 19/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.0913 - accuracy: 0.2130 - val_loss: 1.8843 - val_accuracy: 0.2269
# Epoch 20/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.0939 - accuracy: 0.2222 - val_loss: 1.8846 - val_accuracy: 0.2815
# Epoch 21/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.0281 - accuracy: 0.2238 - val_loss: 1.9114 - val_accuracy: 0.2311
# Epoch 22/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.0216 - accuracy: 0.2210 - val_loss: 1.8699 - val_accuracy: 0.2626
# Epoch 23/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.0421 - accuracy: 0.2202 - val_loss: 1.8546 - val_accuracy: 0.3130
# Epoch 24/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.0454 - accuracy: 0.2180 - val_loss: 1.8931 - val_accuracy: 0.2311
# Epoch 25/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.9838 - accuracy: 0.2448 - val_loss: 1.8632 - val_accuracy: 0.2857
# Epoch 26/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.9968 - accuracy: 0.2217 - val_loss: 1.8904 - val_accuracy: 0.2395
# Epoch 27/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.0086 - accuracy: 0.1968 - val_loss: 1.8466 - val_accuracy: 0.2815
# Epoch 28/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.9491 - accuracy: 0.2384 - val_loss: 1.8452 - val_accuracy: 0.2962
# Epoch 29/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.9567 - accuracy: 0.2252 - val_loss: 1.8587 - val_accuracy: 0.2962
# Epoch 30/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.9868 - accuracy: 0.2457 - val_loss: 1.8558 - val_accuracy: 0.3214
# Epoch 31/200
# 61/61 [==============================] - 0s 4ms/step - loss: 2.0037 - accuracy: 0.1974 - val_loss: 1.8312 - val_accuracy: 0.3025
# Epoch 32/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.9423 - accuracy: 0.2452 - val_loss: 1.8312 - val_accuracy: 0.3151
# Epoch 33/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.9627 - accuracy: 0.2346 - val_loss: 1.8415 - val_accuracy: 0.2962
# Epoch 34/200
# 61/61 [==============================] - 0s 3ms/step - loss: 1.9172 - accuracy: 0.2396 - val_loss: 1.8197 - val_accuracy: 0.3298
# Epoch 35/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.9277 - accuracy: 0.2459 - val_loss: 1.8495 - val_accuracy: 0.3004
# Epoch 36/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.9141 - accuracy: 0.2754 - val_loss: 1.8625 - val_accuracy: 0.2521
# Epoch 37/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8754 - accuracy: 0.2739 - val_loss: 1.8376 - val_accuracy: 0.3025
# Epoch 38/200
# 61/61 [==============================] - 0s 3ms/step - loss: 1.8449 - accuracy: 0.2946 - val_loss: 1.8270 - val_accuracy: 0.2920
# Epoch 39/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8891 - accuracy: 0.2610 - val_loss: 1.8219 - val_accuracy: 0.2941
# Epoch 40/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8521 - accuracy: 0.2853 - val_loss: 1.8176 - val_accuracy: 0.3130
# Epoch 41/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.9151 - accuracy: 0.2492 - val_loss: 1.8200 - val_accuracy: 0.3004
# Epoch 42/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8250 - accuracy: 0.3102 - val_loss: 1.7818 - val_accuracy: 0.3256
# Epoch 43/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8501 - accuracy: 0.2737 - val_loss: 1.8237 - val_accuracy: 0.3361
# Epoch 44/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8695 - accuracy: 0.2639 - val_loss: 1.8135 - val_accuracy: 0.2731
# Epoch 45/200
# 61/61 [==============================] - ETA: 0s - loss: 1.8341 - accuracy: 0.28 - 0s 4ms/step - loss: 1.8369 - accuracy: 0.2807 - val_loss: 1.7775 - val_accuracy: 0.3235
# Epoch 46/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.9028 - accuracy: 0.2514 - val_loss: 1.7879 - val_accuracy: 0.3067
# Epoch 47/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.9119 - accuracy: 0.2684 - val_loss: 1.7891 - val_accuracy: 0.3046
# Epoch 48/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.9030 - accuracy: 0.2881 - val_loss: 1.8049 - val_accuracy: 0.3361
# Epoch 49/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8499 - accuracy: 0.2936 - val_loss: 1.8057 - val_accuracy: 0.2836
# Epoch 50/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8369 - accuracy: 0.2815 - val_loss: 1.7647 - val_accuracy: 0.3256
# Epoch 51/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.8003 - accuracy: 0.3271 - val_loss: 1.7562 - val_accuracy: 0.3403
# Epoch 52/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8473 - accuracy: 0.3319 - val_loss: 1.7674 - val_accuracy: 0.3424
# Epoch 53/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8548 - accuracy: 0.2762 - val_loss: 1.7766 - val_accuracy: 0.3361
# Epoch 54/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8517 - accuracy: 0.2861 - val_loss: 1.7483 - val_accuracy: 0.3235
# Epoch 55/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8278 - accuracy: 0.2873 - val_loss: 1.7814 - val_accuracy: 0.3088
# Epoch 56/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8349 - accuracy: 0.2972 - val_loss: 1.7370 - val_accuracy: 0.3803
# Epoch 57/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7879 - accuracy: 0.3317 - val_loss: 1.7595 - val_accuracy: 0.3277
# Epoch 58/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7950 - accuracy: 0.3136 - val_loss: 1.7531 - val_accuracy: 0.3613
# Epoch 59/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8143 - accuracy: 0.3020 - val_loss: 1.7492 - val_accuracy: 0.3529
# Epoch 60/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.8146 - accuracy: 0.3016 - val_loss: 1.7075 - val_accuracy: 0.3676
# Epoch 61/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7873 - accuracy: 0.3216 - val_loss: 1.7379 - val_accuracy: 0.3571
# Epoch 62/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.7859 - accuracy: 0.3324 - val_loss: 1.7469 - val_accuracy: 0.3613
# Epoch 63/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7994 - accuracy: 0.2903 - val_loss: 1.7265 - val_accuracy: 0.3529
# Epoch 64/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7977 - accuracy: 0.3224 - val_loss: 1.7688 - val_accuracy: 0.2899
# Epoch 65/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.7846 - accuracy: 0.3079 - val_loss: 1.7463 - val_accuracy: 0.3382
# Epoch 66/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7887 - accuracy: 0.2978 - val_loss: 1.7429 - val_accuracy: 0.3655
# Epoch 67/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7270 - accuracy: 0.3776 - val_loss: 1.7092 - val_accuracy: 0.3697
# Epoch 68/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7959 - accuracy: 0.3131 - val_loss: 1.7114 - val_accuracy: 0.3887
# Epoch 69/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7504 - accuracy: 0.3006 - val_loss: 1.7489 - val_accuracy: 0.3214
# Epoch 70/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7781 - accuracy: 0.3152 - val_loss: 1.6889 - val_accuracy: 0.4034
# Epoch 71/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7323 - accuracy: 0.3476 - val_loss: 1.7425 - val_accuracy: 0.3403
# Epoch 72/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.7697 - accuracy: 0.3278 - val_loss: 1.7039 - val_accuracy: 0.3782
# Epoch 73/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6678 - accuracy: 0.3735 - val_loss: 1.6959 - val_accuracy: 0.3908
# Epoch 74/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7344 - accuracy: 0.3299 - val_loss: 1.7151 - val_accuracy: 0.3592
# Epoch 75/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7361 - accuracy: 0.3492 - val_loss: 1.6905 - val_accuracy: 0.3634
# Epoch 76/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7556 - accuracy: 0.3474 - val_loss: 1.7013 - val_accuracy: 0.3613
# Epoch 77/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7104 - accuracy: 0.3572 - val_loss: 1.7126 - val_accuracy: 0.3718
# Epoch 78/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7035 - accuracy: 0.3724 - val_loss: 1.6924 - val_accuracy: 0.3508
# Epoch 79/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6851 - accuracy: 0.3705 - val_loss: 1.6817 - val_accuracy: 0.3950
# Epoch 80/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7207 - accuracy: 0.3628 - val_loss: 1.7005 - val_accuracy: 0.3571
# Epoch 81/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7003 - accuracy: 0.3506 - val_loss: 1.7180 - val_accuracy: 0.3193
# Epoch 82/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6926 - accuracy: 0.3870 - val_loss: 1.7374 - val_accuracy: 0.3151
# Epoch 83/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7034 - accuracy: 0.3634 - val_loss: 1.6910 - val_accuracy: 0.3676
# Epoch 84/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6716 - accuracy: 0.3796 - val_loss: 1.7409 - val_accuracy: 0.3403
# Epoch 85/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7054 - accuracy: 0.3348 - val_loss: 1.7052 - val_accuracy: 0.3739
# Epoch 86/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6941 - accuracy: 0.3276 - val_loss: 1.6612 - val_accuracy: 0.4013
# Epoch 87/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6838 - accuracy: 0.3692 - val_loss: 1.6573 - val_accuracy: 0.3761
# Epoch 88/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6457 - accuracy: 0.3773 - val_loss: 1.6897 - val_accuracy: 0.4118
# Epoch 89/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6553 - accuracy: 0.3547 - val_loss: 1.6835 - val_accuracy: 0.3655
# Epoch 90/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6354 - accuracy: 0.4073 - val_loss: 1.6597 - val_accuracy: 0.3887
# Epoch 91/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.7038 - accuracy: 0.3699 - val_loss: 1.6595 - val_accuracy: 0.4202
# Epoch 92/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6735 - accuracy: 0.3469 - val_loss: 1.6338 - val_accuracy: 0.3718
# Epoch 93/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6398 - accuracy: 0.3603 - val_loss: 1.6310 - val_accuracy: 0.4160
# Epoch 94/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6361 - accuracy: 0.3844 - val_loss: 1.6554 - val_accuracy: 0.3697
# Epoch 95/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6342 - accuracy: 0.3718 - val_loss: 1.6325 - val_accuracy: 0.3950
# Epoch 96/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6196 - accuracy: 0.3878 - val_loss: 1.6048 - val_accuracy: 0.4181
# Epoch 97/200
# 61/61 [==============================] - 0s 3ms/step - loss: 1.6082 - accuracy: 0.3967 - val_loss: 1.6450 - val_accuracy: 0.4181
# Epoch 98/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5817 - accuracy: 0.4045 - val_loss: 1.6155 - val_accuracy: 0.4307
# Epoch 99/200
# 61/61 [==============================] - 0s 3ms/step - loss: 1.6274 - accuracy: 0.4026 - val_loss: 1.6793 - val_accuracy: 0.3887
# Epoch 100/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6375 - accuracy: 0.3802 - val_loss: 1.6204 - val_accuracy: 0.4244
# Epoch 101/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5974 - accuracy: 0.4102 - val_loss: 1.6110 - val_accuracy: 0.4097
# Epoch 102/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5984 - accuracy: 0.3878 - val_loss: 1.6451 - val_accuracy: 0.3739
# Epoch 103/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5781 - accuracy: 0.3843 - val_loss: 1.6191 - val_accuracy: 0.4055
# Epoch 104/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5801 - accuracy: 0.4070 - val_loss: 1.6702 - val_accuracy: 0.3845
# Epoch 105/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5880 - accuracy: 0.3929 - val_loss: 1.6286 - val_accuracy: 0.4118
# Epoch 106/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6291 - accuracy: 0.3966 - val_loss: 1.5970 - val_accuracy: 0.4181
# Epoch 107/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5978 - accuracy: 0.3822 - val_loss: 1.6302 - val_accuracy: 0.4097
# Epoch 108/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5904 - accuracy: 0.3955 - val_loss: 1.6776 - val_accuracy: 0.3613
# Epoch 109/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5621 - accuracy: 0.4339 - val_loss: 1.6372 - val_accuracy: 0.3929
# Epoch 110/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5840 - accuracy: 0.4171 - val_loss: 1.6344 - val_accuracy: 0.3739
# Epoch 111/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5616 - accuracy: 0.4017 - val_loss: 1.5772 - val_accuracy: 0.4286
# Epoch 112/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5525 - accuracy: 0.4106 - val_loss: 1.6495 - val_accuracy: 0.3824
# Epoch 113/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.6076 - accuracy: 0.3647 - val_loss: 1.5799 - val_accuracy: 0.4055
# Epoch 114/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5736 - accuracy: 0.4140 - val_loss: 1.5924 - val_accuracy: 0.4139
# Epoch 115/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5161 - accuracy: 0.4433 - val_loss: 1.5720 - val_accuracy: 0.4349
# Epoch 116/200
# 61/61 [==============================] - 0s 3ms/step - loss: 1.5294 - accuracy: 0.4378 - val_loss: 1.5601 - val_accuracy: 0.4370
# Epoch 117/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5264 - accuracy: 0.4416 - val_loss: 1.6014 - val_accuracy: 0.3866
# Epoch 118/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5366 - accuracy: 0.4212 - val_loss: 1.5816 - val_accuracy: 0.3950
# Epoch 119/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5035 - accuracy: 0.4518 - val_loss: 1.5630 - val_accuracy: 0.4202
# Epoch 120/200
# 61/61 [==============================] - 0s 3ms/step - loss: 1.6095 - accuracy: 0.4005 - val_loss: 1.5790 - val_accuracy: 0.4370
# Epoch 121/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4866 - accuracy: 0.4560 - val_loss: 1.5492 - val_accuracy: 0.4370
# Epoch 122/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4998 - accuracy: 0.4239 - val_loss: 1.5612 - val_accuracy: 0.4370
# Epoch 123/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5425 - accuracy: 0.4009 - val_loss: 1.5527 - val_accuracy: 0.4286
# Epoch 124/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5362 - accuracy: 0.4311 - val_loss: 1.5660 - val_accuracy: 0.3845
# Epoch 125/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5022 - accuracy: 0.4125 - val_loss: 1.5902 - val_accuracy: 0.4223
# Epoch 126/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4877 - accuracy: 0.4385 - val_loss: 1.5681 - val_accuracy: 0.4370
# Epoch 127/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5118 - accuracy: 0.4336 - val_loss: 1.6447 - val_accuracy: 0.3340
# Epoch 128/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4773 - accuracy: 0.4472 - val_loss: 1.6356 - val_accuracy: 0.3697
# Epoch 129/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5426 - accuracy: 0.4063 - val_loss: 1.5396 - val_accuracy: 0.4496
# Epoch 130/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4886 - accuracy: 0.4554 - val_loss: 1.5591 - val_accuracy: 0.4349
# Epoch 131/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5119 - accuracy: 0.4407 - val_loss: 1.5768 - val_accuracy: 0.4139
# Epoch 132/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4878 - accuracy: 0.4371 - val_loss: 1.5399 - val_accuracy: 0.4391
# Epoch 133/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4791 - accuracy: 0.4323 - val_loss: 1.5798 - val_accuracy: 0.3908
# Epoch 134/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4761 - accuracy: 0.4612 - val_loss: 1.5370 - val_accuracy: 0.4664
# Epoch 135/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4582 - accuracy: 0.4521 - val_loss: 1.5972 - val_accuracy: 0.3887
# Epoch 136/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4677 - accuracy: 0.4358 - val_loss: 1.5466 - val_accuracy: 0.4160
# Epoch 137/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.5364 - accuracy: 0.4262 - val_loss: 1.5441 - val_accuracy: 0.4391
# Epoch 138/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3987 - accuracy: 0.4742 - val_loss: 1.5656 - val_accuracy: 0.4328
# Epoch 139/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4674 - accuracy: 0.4633 - val_loss: 1.5258 - val_accuracy: 0.4391
# Epoch 140/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3937 - accuracy: 0.4688 - val_loss: 1.5813 - val_accuracy: 0.4076
# Epoch 141/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4444 - accuracy: 0.4461 - val_loss: 1.5417 - val_accuracy: 0.4265
# Epoch 142/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4664 - accuracy: 0.4454 - val_loss: 1.5460 - val_accuracy: 0.4433
# Epoch 143/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4267 - accuracy: 0.4687 - val_loss: 1.5354 - val_accuracy: 0.4433
# Epoch 144/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4375 - accuracy: 0.4755 - val_loss: 1.5581 - val_accuracy: 0.4328
# Epoch 145/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4338 - accuracy: 0.4573 - val_loss: 1.5171 - val_accuracy: 0.4370
# Epoch 146/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4633 - accuracy: 0.4494 - val_loss: 1.5000 - val_accuracy: 0.4475
# Epoch 147/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4255 - accuracy: 0.4623 - val_loss: 1.5419 - val_accuracy: 0.4328
# Epoch 148/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3636 - accuracy: 0.4932 - val_loss: 1.5318 - val_accuracy: 0.3950
# Epoch 149/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4480 - accuracy: 0.4397 - val_loss: 1.5382 - val_accuracy: 0.4265
# Epoch 150/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.4189 - accuracy: 0.4896 - val_loss: 1.6426 - val_accuracy: 0.3782
# Epoch 151/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3646 - accuracy: 0.5007 - val_loss: 1.5068 - val_accuracy: 0.4496
# Epoch 152/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3859 - accuracy: 0.5058 - val_loss: 1.5331 - val_accuracy: 0.4181
# Epoch 153/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4318 - accuracy: 0.4407 - val_loss: 1.5913 - val_accuracy: 0.4076
# Epoch 154/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4337 - accuracy: 0.4807 - val_loss: 1.5291 - val_accuracy: 0.4307
# Epoch 155/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4807 - accuracy: 0.4392 - val_loss: 1.5027 - val_accuracy: 0.4517
# Epoch 156/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4551 - accuracy: 0.4454 - val_loss: 1.4908 - val_accuracy: 0.4622
# Epoch 157/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3781 - accuracy: 0.5026 - val_loss: 1.5703 - val_accuracy: 0.4412
# Epoch 158/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3585 - accuracy: 0.4757 - val_loss: 1.5063 - val_accuracy: 0.4475
# Epoch 159/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.4243 - accuracy: 0.4558 - val_loss: 1.5195 - val_accuracy: 0.4349
# Epoch 160/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.3694 - accuracy: 0.4485 - val_loss: 1.5249 - val_accuracy: 0.4454
# Epoch 161/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.3849 - accuracy: 0.5018 - val_loss: 1.5260 - val_accuracy: 0.4433
# Epoch 162/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3080 - accuracy: 0.5217 - val_loss: 1.5216 - val_accuracy: 0.4412
# Epoch 163/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3315 - accuracy: 0.5221 - val_loss: 1.5678 - val_accuracy: 0.3866
# Epoch 164/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3823 - accuracy: 0.4844 - val_loss: 1.4871 - val_accuracy: 0.4349
# Epoch 165/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3520 - accuracy: 0.4644 - val_loss: 1.5495 - val_accuracy: 0.4454
# Epoch 166/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3367 - accuracy: 0.5110 - val_loss: 1.4718 - val_accuracy: 0.4727
# Epoch 167/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2900 - accuracy: 0.5238 - val_loss: 1.4767 - val_accuracy: 0.4538
# Epoch 168/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.3325 - accuracy: 0.5233 - val_loss: 1.4748 - val_accuracy: 0.4643
# Epoch 169/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.3391 - accuracy: 0.4921 - val_loss: 1.4711 - val_accuracy: 0.4748
# Epoch 170/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.3572 - accuracy: 0.4688 - val_loss: 1.4845 - val_accuracy: 0.4349
# Epoch 171/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.3281 - accuracy: 0.5072 - val_loss: 1.4981 - val_accuracy: 0.4601
# Epoch 172/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.3790 - accuracy: 0.4595 - val_loss: 1.4745 - val_accuracy: 0.4664
# Epoch 173/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.2711 - accuracy: 0.5373 - val_loss: 1.4799 - val_accuracy: 0.4685
# Epoch 174/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.3588 - accuracy: 0.4930 - val_loss: 1.4569 - val_accuracy: 0.4622
# Epoch 175/200
# 61/61 [==============================] - 0s 6ms/step - loss: 1.2663 - accuracy: 0.5217 - val_loss: 1.4947 - val_accuracy: 0.4601
# Epoch 176/200
# 61/61 [==============================] - 0s 6ms/step - loss: 1.3218 - accuracy: 0.5277 - val_loss: 1.5263 - val_accuracy: 0.4370
# Epoch 177/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.3167 - accuracy: 0.5172 - val_loss: 1.4777 - val_accuracy: 0.4580
# Epoch 178/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3178 - accuracy: 0.5059 - val_loss: 1.4512 - val_accuracy: 0.4874
# Epoch 179/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3325 - accuracy: 0.4722 - val_loss: 1.4855 - val_accuracy: 0.4601
# Epoch 180/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3298 - accuracy: 0.5081 - val_loss: 1.4662 - val_accuracy: 0.4643
# Epoch 181/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2880 - accuracy: 0.5284 - val_loss: 1.4970 - val_accuracy: 0.4496
# Epoch 182/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3039 - accuracy: 0.5301 - val_loss: 1.4613 - val_accuracy: 0.4727
# Epoch 183/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2361 - accuracy: 0.5704 - val_loss: 1.4583 - val_accuracy: 0.4664
# Epoch 184/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2956 - accuracy: 0.5077 - val_loss: 1.4397 - val_accuracy: 0.4517
# Epoch 185/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3070 - accuracy: 0.5127 - val_loss: 1.4952 - val_accuracy: 0.4559
# Epoch 186/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2942 - accuracy: 0.5033 - val_loss: 1.4804 - val_accuracy: 0.4664
# Epoch 187/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2751 - accuracy: 0.5375 - val_loss: 1.4658 - val_accuracy: 0.4517
# Epoch 188/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.3128 - accuracy: 0.5388 - val_loss: 1.4579 - val_accuracy: 0.4685
# Epoch 189/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2638 - accuracy: 0.5472 - val_loss: 1.4903 - val_accuracy: 0.4748
# Epoch 190/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2851 - accuracy: 0.5076 - val_loss: 1.4313 - val_accuracy: 0.4874
# Epoch 191/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2590 - accuracy: 0.5359 - val_loss: 1.4911 - val_accuracy: 0.4475
# Epoch 192/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2279 - accuracy: 0.5567 - val_loss: 1.4840 - val_accuracy: 0.4664
# Epoch 193/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2340 - accuracy: 0.5608 - val_loss: 1.4541 - val_accuracy: 0.4643
# Epoch 194/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2453 - accuracy: 0.5536 - val_loss: 1.4586 - val_accuracy: 0.4727
# Epoch 195/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2288 - accuracy: 0.5343 - val_loss: 1.4803 - val_accuracy: 0.4601
# Epoch 196/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2869 - accuracy: 0.5247 - val_loss: 1.4703 - val_accuracy: 0.4559
# Epoch 197/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2736 - accuracy: 0.5314 - val_loss: 1.4442 - val_accuracy: 0.4664
# Epoch 198/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2105 - accuracy: 0.5392 - val_loss: 1.4468 - val_accuracy: 0.4790
# Epoch 199/200
# 61/61 [==============================] - 0s 4ms/step - loss: 1.2415 - accuracy: 0.5390 - val_loss: 1.4677 - val_accuracy: 0.4496
# Epoch 200/200
# 61/61 [==============================] - 0s 3ms/step - loss: 1.2008 - accuracy: 0.5558 - val_loss: 1.4644 - val_accuracy: 0.4559

# %%
plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(cnnhistory.history['accuracy'])
plt.plot(cnnhistory.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
predictions = model.predict_classes(x_testcnn)
# Out:
# C:\Users\User\anaconda3\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
new_Ytest = y_test.astype(int)

# %%
loss, accuracy = model.evaluate(x_testcnn, y_test)
print("Accuracy: {:.2f}%".format(accuracy*100))

print("Statistics:")
print(classification_report(new_Ytest, predictions))

print("Confusion Matrix:")
cm = confusion_matrix(new_Ytest, predictions)
df_cm = pd.DataFrame(cm)
sn.heatmap(df_cm, annot=True, fmt='')
plt.show()
# Out:
# 15/15 [==============================] - 0s 1ms/step - loss: 1.4644 - accuracy: 0.4559
# Accuracy: 45.59%
# Statistics:
#               precision    recall  f1-score   support
#
#            0       0.43      0.21      0.29        28
#            1       0.64      0.47      0.54        72
#            2       0.40      0.31      0.35        58
#            3       0.43      0.25      0.32        60
#            4       0.52      0.63      0.57        60
#            5       0.63      0.58      0.60        55
#            6       0.29      0.57      0.38        74
#            7       0.55      0.46      0.50        69
#
#     accuracy                           0.46       476
#    macro avg       0.49      0.44      0.44       476
# weighted avg       0.49      0.46      0.46       476
#
# Confusion Matrix:

# %%
model.save('testing10_model.h5')
print("MODEL SAVED")
# Out:
# MODEL SAVED

# %%
new_model=keras.models.load_model('testing10_model.h5')
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 40, 64)            384
# _________________________________________________________________
# activation (Activation)      (None, 40, 64)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 40, 64)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 10, 64)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 10, 128)           41088
# _________________________________________________________________
# activation_1 (Activation)    (None, 10, 128)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 2, 128)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 2, 256)            164096
# _________________________________________________________________
# activation_2 (Activation)    (None, 2, 256)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 256)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 4104
# _________________________________________________________________
# activation_3 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 209,672
# Trainable params: 209,672
# Non-trainable params: 0
# _________________________________________________________________
